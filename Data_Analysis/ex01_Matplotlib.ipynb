# %%
import matplotlib.pyplot as plt
print('hello')
# Out:
# hello

# %% [markdown]
# ### 선 그래프 그리기

# %%
data1 = [10, 14, 19, 20, 25]

# %%
plt.plot(data1)
plt.show()

# %% [markdown]
# @matplotlib inline 명령어는 현재 jupitor notebook이 사용하는 Web Browser에 그림을 그리겠다는 의미(그림을 그리는 Backend를 변경하는 시스템 명령어)
# 이외에도 %matplotlib qt 는 별도의 창읠 띄어서 그림을 그리겠다는 의미

# %%
# %matplotlib inline

# %%
import numpy as np

x = np.arange(-4.5, 5, 0.5)
y = 2 * x ** 2
[x, y]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 여러개 그래프 그리기

# %%
import numpy as np 

x = np.arange(-4.5, 5, 0.5)
y1 = 2 * x **2
y2 = 5 * x + 30
y3 = 4 * x **2 + 10

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.show()

# %%
plt.plot(x, y1, x, y2, x, y3)
plt.show()

# %% [markdown]
# ### figure 바꿔서 그려보기

# %%
plt.plot(x, y1)

plt.figure()
plt.plot(x, y2)
plt.show()

# %% [markdown]
# ### figure를 여러개 만들고 figure를 지정해서 그림을 그리기

# %%
import numpy as np

# 데이터 생성
x = np.arange(-5, 5, 0.1)
y1 = x ** 2 - 2
y2 = 20 * np.cos(x) ** 2

plt.figure(1)       # 1번 그래프 창을 생성 
plt.plot(x, y1)     # 지정된 그래프 창에 그래프를 그림

plt.figure(2)       # 2번 그래프 창을 생성함
plt.plot(x, y2)     # 지정된 그래프 창에 그래프를 그림

plt.figure(1)       # 이미 생성된 1번 그래프 창을 지정함
plt.plot(x, y2)     # 지정된 그래프 창에 그래프를 그림

plt.figure(2)       # 이미 생성된 2번 그래프 창을 지정함
plt.clf()           # 2번 그래프 창에 그려진 모든 그래프를 지움
plt.plot(x, y1)     # 지정된 그래프 창에 그래프를 그림

plt.show()

# %% [markdown]
# ### subplot 사용

# %%
# 데이터 생성
x = np.arange(0, 10, 0.1)
y1 = 0.3*(x-5)**2 + 1
y2 = -1.5*x + 3
y3 = np.sin(x) ** 2
y4 = 10 * np.exp(-x) + 1

# 2 x 2 행렬로 이뤄진 하위 그래프에서 p에 따라 위치를 지정
plt.subplot(2, 2, 1)
plt.plot(x, y1)

plt.subplot(2,2,2)
plt.plot(x, y2)

plt.subplot(2,2,3)
plt.plot(x, y3)

plt.subplot(2,2,4)
plt.plot(x, y4)

plt.show()

# %% [markdown]
# ### 그래프의 출력 범위 지정하기

# %%
import numpy as np
x = np.linspace(-4, 4, 100)
y1 = x**3
y2 = 10 * x ** 2 - 2

plt.plot(x, y1, x, y2)

plt.show()

# %%
# xlim, ylim을 사용해서 x, y축의 영역을 지정한다.
plt.plot(x, y1, x, y2)
plt.xlim(-1, 1)
plt.ylim(-3, 3)

plt.show()

# %% [markdown]
# ### 그래프 꾸미기

# %%
import numpy as np
x = np.arange(0, 5, 1)

y1 = x
y2 = x + 1
y3 = x + 2
y4 = x + 3

plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
# 선의 색 변경
plt.plot(x, y1, 'm', x, y2, 'y', x, y3, 'k', x, y4, 'c')
plt.show()

# b : blue, g : green, r : red, c : cyan, m : magenta, y : yellow, k : black, w : white

# %%
# 선의 유형 변경
plt.plot(x, y1, '-', x, y2, '--', x, y3, ':', x, y4, '-.')
plt.show()

# %%
# 점 표시형태 변경
plt.plot(x, y1, 'o', x, y2, '^', x, y3, 's', x, y4, 'd')
plt.show()

# %%
# 조합해서 사용 

plt.plot(x, y1, '>--r', x, y2, 's-g', x, y3, 'd:b', x, y4, '-.Xc')
plt.show()

# %% [markdown]
# ### 라벨, 제목, 격자, 범례, 문자열 표시

# %%
# x축명, y축명을 표시
import numpy as np

x = np.arange(-4.5, 5, 0.5)
y = 2*x**3

plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# 그림의 제목을 표시
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Graph title')

# 그리드 표시 (plt.grid() 도 가능)
plt.grid(True)
plt.show()

# %%
import numpy as np
x = np.arange(0, 5, 1)

y1 = x
y2 = x + 1
y3 = x + 2
y4 = x + 3

plt.plot(x, y1, '>--r', x, y2, 's-g', x, y3, 'd:b', x, y4, '-.Xc')

# 선에 Label(이름)을 표시, label의 위치를 지정할 수 있음
plt.legend(['data1', 'data2', 'data3', 'data4'], loc = 'lower right')        
plt.show()

# %% [markdown]
# ### 문자열을 특정위치에 위치시킨다

# %%
import numpy as np
x = np.arange(0, 5, 1)

y1 = x
y2 = x + 1
y3 = x + 2
y4 = x + 3

plt.plot(x, y1, '>--r', x, y2, 's-g', x, y3, 'd:b', x, y4, '-.Xc')
plt.text(0, 6, "text 1")
plt.text(0, 5, "text 2")
plt.text(3, 1, "text 3")
plt.text(3, 0, "text 4")
plt.show()

# %% [markdown]
# ### 산점도

# %%
import matplotlib.pyplot as plt

height = [165, 177, 160, 180,185, 155, 172]
weight = [62, 67, 55, 74, 90, 43, 64]

plt.scatter(height, weight)
plt.xlabel('Height(m)')
plt.ylabel('Weight(Kg)')
plt.title('Height & Weight')
plt.grid(True)

# %%
# 점(마커)의 크기 및 색 변경
plt.scatter(height, weight, s=500, c='r')   # 마커 크기는 500, 컬러는 붉은색(red)
plt.show()

# %%
# 데이터 별로 마커의 크기 및 색 지정
size = 100 * np.arange(1, 8)
colors = ['r', 'g', 'b', 'c', 'm', 'k', 'y']        # 데이터 별로 마커의 컬러 지정

plt.scatter(height, weight, s=size, c=colors)
plt.show()

# %%
# 위도, 경도를 x, y 축으로 대한민국 도시별 인구 밀도를 색상과 점의 크기로 표현하는 그림 그리기

import numpy as np

city = ['Seoul', 'Incheon', 'Dajeon', 'Daegu', 'Alsan', 'Busan', 'Gwangu']

# 위도와 경도
lat = [37.56, 37.45, 36.35, 35.87, 35.53, 35.18, 35.16]
lon = [126.97, 126.70, 127.38, 128.60, 129.31, 129.07, 126.85]

# 인구 밀도(명/km^2): 2017년 통계청 자료
pop_den = [16154, 2751, 2839, 2790, 1099, 4454, 2995]

size = np.array(pop_den) * 0.2
colors = ['r', 'g', 'b', 'c', 'm', 'k', 'y']

plt.scatter(lon, lat, s=size, c=colors, alpha=0.5)  # alpha는 색상의 투명도
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Population density by region(2017)')

for x, y, name in zip(lon, lat, city):
    plt.text(x, y, name)
    
    
plt.show()

# %% [markdown]
# ### 막대 그래프

# %%
member_IDs = ['m_01', 'm_02', 'm_03', 'm_04']
before_ex = [27, 35, 40, 33]
after_ex = [30, 38, 42, 37]

# %%
import matplotlib.pyplot as plt
import numpy as np

n_data = len(member_IDs)
index = np.arange(n_data)

plt.bar(index, before_ex)
plt.show()

# %%
plt.bar(index, before_ex, tick_label=member_IDs)
plt.show()

# %%
colors = ['r', 'g', 'b', 'm']
plt.bar(index, before_ex, color=colors, tick_label = member_IDs)
plt.show()

# %%
# 막대그래프의 폭을 조정
plt.bar(index, before_ex, tick_label=member_IDs, width=0.6)
plt.show()

# %%
# 수평으로 출력
colors=['r', 'g', 'b', 'm']
plt.barh(index, before_ex, color=colors, tick_label = member_IDs)
plt.show()

# %%
# 운동 전, 후의 데이터를 비교해서 출력
barWidth = 0.4
plt.bar(index, before_ex, color='c', align='edge', width=barWidth, label='before')
plt.bar(index + barWidth, after_ex, color = 'm', align='edge', width=barWidth, label='after')

plt.xticks(index + barWidth, member_IDs)
plt.legend()
plt.xlabel('member ID')
plt.ylabel('sit-ups count')
plt.title('compare before and after')
plt.show()

# %% [markdown]
# ### 히스토그램

# %%
import matplotlib.pyplot as plt

math = [76, 82, 84, 83, 90, 86, 85, 92, 72, 71, 100, 87, 81, 76, 94, 78, 81, 60 ,79, 69, 74, 87, 82, 68, 79]
plt.hist(math)
# Out:
# (array([1., 0., 3., 2., 5., 5., 5., 1., 2., 1.]),
#  array([ 60.,  64.,  68.,  72.,  76.,  80.,  84.,  88.,  92.,  96., 100.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(math, bins=8)      # hist() 함수의 bins 파라미터는 히스토그램의 가로축 구간의 개수를 지정

plt.xlabel('grade')
plt.ylabel('frequency')
plt.title('histogram of math test')
plt.grid()
plt.show()

# %% [markdown]
# ### 파이 그래프

# %%
fruit = ['apple', 'banana', 'strawberry', 'orange', 'grape']
result = [7, 6, 3, 2, 2]

# %%
import matplotlib.pyplot as plt

plt.pie(result)
plt.show()

# %%
# 그래프의 사이즈 설정 : plt.figure 메소드에 figsize 옵션을 설정 아래와 같은 형식으로 입력
plt.figure(figsize=(5,5))
plt.pie(result)
plt.show()

# %%
# autopct는 부채꼴 안에 표시될 숫자의 형식을 지정
plt.figure(figsize=(5,5))
plt.pie(result, labels=fruit, autopct='%.1f%%')
plt.show()

# %%
# startrangle 는 부채꼴이 그려지는 시작 각도를 설정, counterclock=False로 설정시 시계 방향 순서로 부채꼴 영역이 표시
plt.figure(figsize=(5,5))
plt.pie(result, labels=fruit, autopct='%.1f%%', startangle=90, counterclock=False)
plt.show()

# %%
# explode는 부채꼴이 파이 차트의 중심에서 벗어나는 정도를 설정
explode_value = (0.1, 0, 0, 0, 0)
plt.figure(figsize=(5,5))
plt.pie(result, labels=fruit, autopct='%.1f%%', startangle=90, counterclock=False, explode=explode_value, shadow=True)
plt.show()

# %% [markdown]
# ### 그래프 저장하기
#
# rcParams 으로 값을 바꿔주면, backend에서 그릴 때 다른 방식으로 그리게 됨
# 그래프의 폰트 사이즈, 크기, 바탕색 등 여러가지를 변경할 수 있다

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
mpl.rcParams['figure.dpi']
# Out:
# 100.0

# %%
# 그린 그림을 파일로 저장
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 1)
y1 = x
y2 = x + 1
y3 = x + 2
y4 = x + 3

plt.plot(x, y1, x, y2, x, y3, x, y4)

plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')

# 그래프를 이미지 파일로 저장, dpi는 100으로 설정
plt.savefig('saveFigTest1.png', dpi=100)
plt.show()
